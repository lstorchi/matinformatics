# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.options.display.max_rows = 120

# %%
dataset = pd.read_excel('Data_Ghiringhelli.xlsx')

# %%
import matplotlib.pyplot as plt
from matplotlib  import cm
import numpy as np

fig = plt.figure(figsize=(10,10))

#ax.grid(True,linestyle='-',color='0.75')
x = dataset['ZA'].values
y = dataset['ZB'].values
z = np.array(dataset['a0(RS)'] - dataset['a0(ZB)'])


# scatter with colormap mapping to z value
#ax = ax.scatter(x,y,c=z, marker = 'o', cmap = cm.jet );


#---------------------------------
fig, ax = plt.subplots(figsize=(10,8))
im = ax.scatter(x, y, c=z,  cmap=plt.cm.jet)

# Add a colorbar
fig.colorbar(im, ax=ax)

plt.show()

# %% [markdown]
# #### Here I haven't got any data in plus region opposite to the paper. I am not sure if I have the problem with data or some other coding problem

# %%
#### In the paper they were plotting DE , that is the plot i Put in the Google Sheet
